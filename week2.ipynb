# %% [markdown]
# <a href="https://colab.research.google.com/github/JARAM2021/NLP_Study/blob/Juwon/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4MB 64.5MB/s
# ...
#      |████████████████████████████████| 92kB 12.0MB/s
# ...
#      |████████████████████████████████| 460kB 54.2MB/s
# ...
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
pip install gensim

# %%
pip install -U gensim
# Out:
# ...
#      |████████████████████████████████| 24.2MB 1.7MB/s
# ...
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# ...

# %%
pip install scipy

# %%
from google.colab import drive
drive.mount('//content/drive')
# Out:
# Mounted at //content/drive

# %%
solo_raw = open('/content/drive/MyDrive/NLP/data/solo.txt').read()

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
solo_noun = okt.nouns(solo_raw[:500000])

# %%
from gensim.models import  word2vec

# %%
print(solo_noun)
# Out:
# ['중학교', '때', '이해', '안', '정말', '버튼', '클릭', '자동', '사냥', '게', '핸드폰', '게임', '사람', '난', '게임', '게', '원래', '본인', '컨트롤', '맛', '뭘', '느낌', '성취', '것', '버튼', '하나', '캐릭터', '몬스터', '이', '게임', '구경', '게임', '말', '거', '맛', '얼마나', '나', '자동', '사냥', '즐거움', '보지', '시스템', '핸드폰', '게임', '손', '안', '전혀', '향후', '내', '인생', '자동', '사냥', '아주', '관계', '것', '게임', '이야기', '것', '나', '실제', '자동', '사냥', '것', '나이', '스물', '쯤', '여자', '의도', '가지', '말', '대충', '감', '오기', '마련', '너', '향상', '심', '헤어지자', '이야기', '향상', '심', '언제', '고깃집', '알바', '살', '일단', '유성은', '아르바이트', '생', '알바생', '건', '고등학생', '일', '때', '대학교', '첫', '학년', '학기', '전', '유성은', '즉시', '휴학', '고등학생', '일', '때', '일', '음식점', '취직', '제대로', '일', '요식업', '흥미', '유성', '지금껏', '일', '사장', '엄지', '만', '말', '내', '가게', '돈', '실제', '유성', '통장', '장고', '온', '잔고', '꽤', '언제', '서른', '한참', '그때', '유럽', '여행', '번', '제대로', '못', '그때', '가게', '차려', '일만', '계속', '되풀이', '그게', '무슨', '의미', '너', '뭐', '여자친구', '지영은', '학벌', '무척', '직장', '역시', '그', '전도', '유망', '수', '그것', '유성', '차이', '자신', '능력', '알', '능력', '수', '일', '파악', '그
# ...

# %%
f = open('/content/drive/MyDrive/NLP/data/solo_noun.txt', 'w')
for i in solo_noun:
    f.write(i)
    f.write('\n')

# %%
sents = word2vec.Text8Corpus('/content/drive/MyDrive/NLP/data/solo_noun.txt')
model = word2vec.Word2Vec(sents, size=16, window=5, min_count=10, sg=1, hs=1, iter=500, workers=4)
model.save('/content/drive/MyDrive/NLP/solo.model')
print("model saved")
# Out:
# model saved

# %%
model = word2vec.Word2Vec.load('/content/drive/MyDrive/NLP/solo.model')
print(model)
# Out:
# Word2Vec(vocab=1474, size=16, alpha=0.025)

# %%
try:
  y1 = model.wv.similarity('자동', '버튼')
except KeyError:
  y1 = -1
print(y1)
# Out:
# 0.7543361

# %%
y2 = model.most_similar("사냥", topn=5)
for item in y2:
  print(item)
# Out:
# ('자동', 0.898722767829895)
# ('노력', 0.8289620876312256)
# ('터', 0.7411410808563232)
# ('체력', 0.7320199012756348)
# ('확보', 0.7300156354904175)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
y2 = model.most_similar(["사냥","자동"], topn=5)
for item in y2:
  print(item)
# Out:
# ('노력', 0.8297386765480042)
# ('최선', 0.7536158561706543)
# ('연습', 0.7431591153144836)
# ('이용', 0.7415131330490112)
# ('위협', 0.7396466732025146)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
